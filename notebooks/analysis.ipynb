# %%
import os
import sys

from IPython.display import clear_output

# %%
os.chdir("../")

# %%
from utils.analysis import plot_paired_delta

configs = {
    'db_conformer (n_repeats = 1, 5)':{
        'baseline': ({'n_repeats': 5}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
    },
    'mtf_c (n_repeats = 1, 5)': {
        'baseline': ({'n_repeats': 5}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.0}, 'mtf_c'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.0}, 'mtf_c'),
    }
}


plot_paired_delta(
    config_pairs=configs,
    reference_key='baseline',
    root_dir='experiments/classification/frequency_backbone',
    save_path='plots/classification/frequency_backbone',
    filename='dbconformer_mtfc_loso_nrepeats_comparison',
    figsize=(12, 6),
    metric='mean_acc',
    hline=None
)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <Axes: title={'center': 'Paired Comparison – Relative Delta (%)'}, ylabel='Mean Acc Relative Delta (%)'>)

# %%
from utils.analysis import plot_comparison_bars

configs = {
    'db_conformer (depth=2)': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
    'db_conformer (depth=1)': ({'n_repeats': 1}, {'chn_depth': 1}, 'db_conformer'),
    'mtf_c ($\lambda = 0.001$, depth=2)': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.001}, 'mtf_c'),
    'mtf_c ($\lambda = 0.001$, depth=1)': ({'n_repeats': 1}, {'chn_depth': 1, 'tem_depth': 1, 'spec_depth': 1, 'reconstruction_lambda':0.001}, 'mtf_c'),
    'mtf_c ($\lambda = 0.01$, depth=2)': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.01}, 'mtf_c'),
    'mtf_c ($\lambda = 0.01$, depth=1)': ({'n_repeats': 1}, {'chn_depth': 1, 'tem_depth': 1, 'spec_depth': 1, 'reconstruction_lambda':0.01}, 'mtf_c'),
}

plot_comparison_bars(
    config_pairs=configs,
    root_dir='experiments/classification/frequency_backbone',
    save_path='plots/classification/frequency_backbone',
    filename='dbconformer_mtfc_barplot_comparison',
    figsize=(14, 8),
    metric='mean_acc',
    error_metric='std_acc'
)

clear_output()

# %%
from utils.analysis import plot_paired_delta

configs = {
    'mtf_c (depth=2, $\lambda$=0.0)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.0}, 'mtf_c'),
    },
    'mtf_c (depth=2, $\lambda$=0.001)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.001}, 'mtf_c'),
    },
    'mtf_c (depth=2, $\lambda$=0.01)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2, 'reconstruction_lambda':0.01}, 'mtf_c'),
    },
}


plot_paired_delta(
    config_pairs=configs,
    reference_key='baseline',
    root_dir='experiments/classification/frequency_backbone',
    save_path='plots/classification/frequency_backbone',
    filename='dbconformer(depth=2)_mtfc(depth=2)_comparison',
    figsize=(12, 6),
    metric='mean_acc',
    hline=None
)

clear_output()

# %%
from utils.analysis import plot_paired_delta

configs = {
    'mtf_c (depth=1, $\lambda$=0.0)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 1, 'tem_depth': 1, 'spec_depth': 1, 'reconstruction_lambda':0.0}, 'mtf_c'),
    },
    'mtf_c (depth=1, $\lambda$=0.001)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 1, 'tem_depth': 1, 'spec_depth': 1, 'reconstruction_lambda':0.001}, 'mtf_c'),
    },
    'mtf_c (depth=1, $\lambda$=0.01)':{
        'baseline': ({'n_repeats': 1}, {'chn_depth': 2}, 'db_conformer'),
        'experiment': ({'n_repeats': 1}, {'chn_depth': 1, 'tem_depth': 1, 'spec_depth': 1, 'reconstruction_lambda':0.01}, 'mtf_c'),
    },
}


plot_paired_delta(
    config_pairs=configs,
    reference_key='baseline',
    root_dir='experiments/classification/frequency_backbone',
    save_path='plots/classification/frequency_backbone',
    filename='dbconformer(depth=2)_mtfc(depth=1)_comparison',
    figsize=(12, 6),
    metric='mean_acc',
    hline=None
)

clear_output()

# %%
# from utils.analysis import plot_lambda_sweep

# plot_lambda_sweep(
#     root_dir='experiments/classification/frequency_backbone',
#     save_path='plots/classification/frequency_backbone',
#     filename='loso_repeats=1|transformer_depth=2|lambda_sweep',
#     figsize=(14, 8),
#     training_params={'n_repeats': 1},
#     model_params={'chn_depth': 2, 'tem_depth': 2, 'spec_depth': 2},
#     sweep_lambdas=[0.001, 0.01]
# )
