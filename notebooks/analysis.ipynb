# %%
import os
import sys

# %%
os.chdir("../")

# %%
from utils.analysis import plot_lambda_sweep

plot_lambda_sweep(
    root_dir='experiments/classification/frequency_backbone',
    save_path='plots/classification/frequency_backbone',
    filename='loso_repeats=5|lambda_sweep',
    figsize=(14, 8),
    n_repeats=5,
    sweep_lambdas=[0.0, 0.001, 0.01, 0.1, 0.5, 1.0]
)
# Out:
# (<Figure size 1680x960 with 1 Axes>,
#  <Axes: title={'center': 'Effect of Reconstruction Weight on Classification Accuracy'}, xlabel='Reconstruction $\\lambda$', ylabel='LOSO Accuracy $\\Delta$ vs DBConformer (%)'>)
